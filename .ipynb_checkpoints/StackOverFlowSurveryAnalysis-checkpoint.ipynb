# %% [markdown]
# I read stack overflow survey report, and you know what, amazingly, it has public dataset. Wow! It intrigued me to explore dataset for exploratory data analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML

# %%
data_schema = pd.read_csv('survey-results-schema.csv')
data = pd.read_csv('survey-results-public.csv')

# %% [markdown]
# Alright, the successful execution of above statement ensures that data is being loaded without exception.
#
# Le'me Roll up my sleeves, because now is the time to dig this data and transform it into information.

# %% [markdown]
# Umm, first things first. Let's explore:
# - How many data points exist in the dataset?
# - How many features are there in the dataset?

# %%
data.shape
# Out:
# (51392, 154)

# %% [markdown]
# Interesting! It seems like a large feature vector i.e <$v_{1}$, $v_{2}$, $v_{3}$, ..., $v_{154}$)
#
# Let's see what are these features exactly! This will help to formulate questions, if we're exploring data!

# %%
data_schema
# Out:
#                           Column  \
# 0                     Respondent
# 1                   Professional
# 2                   ProgramHobby
# 3                        Country
# 4                     University
# 5               EmploymentStatus
# 6                FormalEducation
# 7                 MajorUndergrad
# 8                     HomeRemote
# 9                    CompanySize
# 10                   CompanyType
# 11                  YearsProgram
# 12                 YearsCodedJob
# 13             YearsCodedJobPast
# 14                 DeveloperType
# 15              WebDeveloperType
# 16           MobileDeveloperType
# 17              NonDeveloperType
# 18            CareerSatisfaction
# 19               JobSatisfaction
# 20                 ExCoderReturn
# 21               ExCoderNotForMe
# 22                ExCoderBalance
# 23                ExCoder10Years
# 24               ExCoderBelonged
# 25                 ExCoderSkills
# 26            ExCoderWillNotCode
# ...

# %% [markdown]
# Oops! Text is truncated. It's kinda difficult to read survey questions. I can solve it by writing a line code.

# %%
pd.set_option('display.max_colwidth', -1)

# %%
data_schema
# Out:
#                           Column  \
# 0    Respondent
# 1    Professional
# 2    ProgramHobby
# 3    Country
# 4    University
# 5    EmploymentStatus
# 6    FormalEducation
# 7    MajorUndergrad
# 8    HomeRemote
# 9    CompanySize
# 10   CompanyType
# 11   YearsProgram
# 12   YearsCodedJob
# 13   YearsCodedJobPast
# 14   DeveloperType
# 15   WebDeveloperType
# 16   MobileDeveloperType
# 17   NonDeveloperType
# 18   CareerSatisfaction
# 19   JobSatisfaction
# 20   ExCoderReturn
# 21   ExCoderNotForMe
# 22   ExCoderBalance
# 23   ExCoder10Years
# 24   ExCoderBelonged
# 25   ExCoderSkills
# 26   ExCoderWillNotCode
# 27   ExCoderActive
# 28   PronounceGIF
# 29   ProblemSolving
# ..              ...
# 124  InfluenceRecruitment
# 125  InfluenceCommunication
# 126  StackOverflowDescribes
# 127  StackOverflowSatisfaction
# 128  StackOverflowDevices
# 129  StackOverflowFoundAnswer
# 130  StackOverflowCopiedCode
# 131  StackOverflowJobListing
# 132  StackOverflowCompanyPage
# ...

# %% [markdown]
# Great! But wait, I can only see rows 124 to 153 after row 29. Seems like rows are also truncated. Let me fix it.

# %%
pd.set_option('display.max_rows', 200)

# %%
data_schema
# Out:
#                                Column  \
# 0    Respondent
# 1    Professional
# 2    ProgramHobby
# 3    Country
# 4    University
# 5    EmploymentStatus
# 6    FormalEducation
# 7    MajorUndergrad
# 8    HomeRemote
# 9    CompanySize
# 10   CompanyType
# 11   YearsProgram
# 12   YearsCodedJob
# 13   YearsCodedJobPast
# 14   DeveloperType
# 15   WebDeveloperType
# 16   MobileDeveloperType
# 17   NonDeveloperType
# 18   CareerSatisfaction
# 19   JobSatisfaction
# 20   ExCoderReturn
# 21   ExCoderNotForMe
# 22   ExCoderBalance
# 23   ExCoder10Years
# 24   ExCoderBelonged
# 25   ExCoderSkills
# 26   ExCoderWillNotCode
# 27   ExCoderActive
# 28   PronounceGIF
# 29   ProblemSolving
# 30   BuildingThings
# 31   LearningNewTech
# 32   BoringDetails
# 33   JobSecurity
# 34   DiversityImportant
# 35   AnnoyingUI
# 36   FriendsDevelopers
# 37   RightWrongWay
# 38   UnderstandComputers
# 39   SeriousWork
# 40   InvestTimeTools
# 41   WorkPayCare
# 42   KinshipDevelopers
# ...

# %% [markdown]
# Hooray! It's ready to explore.

# %% [markdown]
# ### Let's see if programming can be a hobby or just a way to earn handsome amount

# %%
programHobby = data['ProgramHobby'].value_counts()
#Code to draw plot
labels = ['Yes, I program as a hobby','Yes, both', 'No', 'Yes, I contribute to open source projects']
programHobby = list(programHobby)
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.05, 0, 0, 0.3)  # explode 1st slice

# Plot
plt.pie(programHobby, explode=explode, labels=labels, colors=colors,
autopct=lambda p: '{:.0f}'.format((p/100)*sum(programHobby)), shadow=True, startangle=140)
plt.axis('equal')
plt.show()

# %% [markdown]
# Sounds interesting. Right! So, a large number of people who are actively visiting stack overflow program because it excites them.

# %% [markdown]
# ### Question

# %%
profession = data['Professional'].value_counts()
professional = list(profession)
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'black']
labels = ['Professional\ndeveloper', 'Student', 'Professional\nnon-developer\n who\nsometimes\nwrites code', 'Used to\nbe a\nprofessional\ndeveloper', 'None of these']
plt.title('Which of the following best describes you?')
plt.bar(labels, professional,width=0.5, align='center', alpha=0.5, color=colors)
plt.show()
profession_developer_count = professional[0]

# %% [markdown]
# There are more than 35000 professionals who use stack overflow.
# #### "Applaudable moment for team Stack Overflow!"

# %%
display(HTML('<iframe src="https://giphy.com/embed/l2JdVRfJozpjq70SA" width="480" height="362" frameBorder="0" class="giphy-embed" allowFullScreen></iframe><p><a href="https://giphy.com/gifs/season-4-the-simpsons-4x2-l2JdVRfJozpjq70SA">via GIPHY</a></p>'));
# Out:
# <iframe src="https://giphy.com/embed/l2JdVRfJozpjq70SA" width="480" height="362" frameBorder="0" class="giphy-embed" allowFullScreen></iframe><p><a href="https://giphy.com/gifs/season-4-the-simpsons-4x2-l2JdVRfJozpjq70SA">via GIPHY</a></p>

# %% [markdown]
# ### Let's see how many hobbist programmers pursuing it as a profession

# %%
hobbyProfessionalDeveloper = len(data[(data['Professional']=='Professional developer') & (data['ProgramHobby']=='Yes, I program as a hobby')])
str((hobbyProfessionalDeveloper/profession_developer_count)*100) + " %"
# Out:
# '45.21048407184966 %'

# %% [markdown]
# ### Which country has more professional developers who use stack overflow?

# %%
professionalDeveloper = data[data['Professional']=='Professional developer']['Country'].value_counts()
professionalDeveloper[:5]
# Out:
# United States     8310
# India             3438
# United Kingdom    3302
# Germany           2767
# Canada            1605
# Name: Country, dtype: int64

# %% [markdown]
# ![alt text](map.png "Title")

# %%
salary = data['Salary'].value_counts()
salary
# Out:
# 120000.000000    167
# 110000.000000    164
# 100000.000000    155
# 75000.000000     149
# 60000.000000     139
# 90000.000000     136
# 50000.000000     135
# 32258.064516     132
# 43010.752688     129
# 53763.440860     128
# 80000.000000     128
# 64516.129032     117
# 65000.000000     114
# 70000.000000     113
# 48387.096774     110
# 38709.677419     99
# 85000.000000     97
# 130000.000000    94
# 125000.000000    91
# 115000.000000    90
# 45161.290323     87
# 150000.000000    85
# 105000.000000    85
# 40000.000000     81
# 62500.000000     80
# 37634.408602     79
# 95000.000000     78
# 140000.000000    71
# 51612.903226     71
# 59139.784946     71
# 55000.000000     68
# 43750.000000     68
# 135000.000000    67
# 56250.000000     60
# 45454.545455     59
# 21505.376344     57
# 37500.000000     56
# 26881.720430     56
# 45000.000000     53
# 25806.451613     53
# 52500.000000     52
# 69892.473118     50
# 34408.602151     47
# 30000.000000     47
# ...

# %% [markdown]
# ### Which Professionals earn more than 100000?

# %%
salaryGreater = data[data['Salary']>=100000]['Professional'].value_counts()
salaryGreater
# Out:
# Professional developer    2050
# Name: Professional, dtype: int64

# %% [markdown]
# So out of all professionals who participated in stack overflow developer survey, only professional developer $100000 or more.
#
# Now I am interested to know which countries pay this amount out of all!

# %% [markdown]
# ### Which countries pay $100000 or more to professional developers?

# %%
countryPaysGreater = data[(data['Salary']>=100000) & (data['Professional']=="Professional developer")]['Country'].value_counts()
countryPaysGreater[:10]
# Out:
# United States     1725
# Switzerland       65
# United Kingdom    65
# Australia         30
# Canada            29
# Israel            27
# Germany           19
# Denmark           11
# Norway            10
# France            9
# Name: Country, dtype: int64

# %% [markdown]
# Better opportunities in Switzerland and Australia for developers.

# %% [markdown]
# Now, let's check which attributes have null values.

# %%
col_null = set(data.columns[data.isnull().sum()>0])

# %%
nullLength = len(col_null)
notNullLength = data.shape[1]-nullLength

# %%
labels = ['Null', 'Not Null']
size = [nullLength, notNullLength]
fig1, ax1 = plt.subplots()
ax1.pie(size, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')
plt.show()

# %% [markdown]
# So, 95% of the attributes contain null values.

# %%
len(most_missing_cols) = set(data.columns[data.isnull().mean()>0.50])
# Out:
#   File "<ipython-input-25-a07dd91f50d0>", line 1
#     len(most_missing_cols) = set(data.columns[data.isnull().mean()>0.50])
#                                                                          ^
# SyntaxError: can't assign to function call

# %%
len(most_missing_cols)/147
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-1e63909991a8> in <module>
# ----> 1 len(most_missing_cols)/147
#
# NameError: name 'most_missing_cols' is not defined

# %% [markdown]
# Out of 147 attributes, 36% attributes has 50% missing values. Still 64% attributes has no null data.

# %%
labels = ['Null', 'Not Null']
size = [len(most_missing_cols), len(col_null)]
fig1, ax1 = plt.subplots()
ax1.pie(size, labels=labels, autopct='%1.1f%%', shadow=True)
ax1.axis('equal')
plt.show()
